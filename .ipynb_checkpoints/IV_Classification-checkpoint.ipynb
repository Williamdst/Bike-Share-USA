# %% [markdown]
# ## Connecting to the Database

# %%
pip install psycopg2-binary;
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2

# %%
# Put the password in 
PGHOST = 'tripdatabase2.cmaaautpgbsf.us-east-2.rds.amazonaws.com'
PGDATABASE = ''
PGUSER = 'postgres'
PGPASSWORD = 'Josh1234'

# %%
# Database Context Manager
try:   
    # Set up a connection to the postgres server.    
    conn = psycopg2.connect(user = PGUSER,
                            port = "5432",
                            password = PGPASSWORD,
                            host = PGHOST,
                            database = PGDATABASE)
    # Create a cursor object
    cursor = conn.cursor()   
    cursor.execute("SELECT version();")
    record = cursor.fetchone()
    print("Connection Success:", record,"\n")

except (Exception, psycopg2.Error) as error:
    print("Error while connecting to PostgreSQL", error)
# Out:
# Connection Success: ('PostgreSQL 12.4 on x86_64-pc-linux-gnu, compiled by gcc (GCC) 4.8.5 20150623 (Red Hat 4.8.5-11), 64-bit',)

# %%
import pandas as pd
import numpy as np
import Queries
import matplotlib.pyplot as plt
import seaborn as sns
import importlib

# %%
description_query = """SELECT * FROM lookup"""
lookup_table = Queries.execute_query(conn, description_query, to_frame=True)

# %%
pd.set_option('display.max_colwidth', -1)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.

# %%
lookup_table[lookup_table.alias.str[:3] == 'DEM']
# Out:
#     alias                                          indicator  \
# 0   DEM1   Born in New York State
# 1   DEM2   Disabled population
# 2   DEM3   Foreign-born population
# 3   DEM4   Households with children under 18 years old
# 4   DEM5   Income diversity ratio
# 5   DEM6   Labor force participation rate
# 6   DEM7   Median household income (2019$)
# 7   DEM8   Median household income, homeowners (2019$)
# 8   DEM9   Median household income, renters (2019$)
# 9   DEM10  Percent Asian
# 10  DEM11  Percent Black
# 11  DEM12  Percent Hispanic
# 12  DEM13  Percent white
# 13  DEM14  Population
# 14  DEM15  Population aged 25+ without a high school diploma
# 15  DEM16  Population aged 65+
# 16  DEM17  Poverty rate
# 17  DEM18  Poverty rate, population aged 65+
# 18  DEM19  Poverty rate, population under 18 years old
# 19  DEM20  Racial diversity index
# 20  DEM21  Single-person households
# 21  DEM22  Unemployment rate
#
# ...

# %%
lookup_table[lookup_table.alias.str[:3] == 'HSC']
# Out:
#     alias  \
# 22  HSC1
# 23  HSC2
# 24  HSC3
# 25  HSC4
# 26  HSC5
# 27  HSC6
# 28  HSC7
# 29  HSC8
# 30  HSC9
# 31  HSC10
# 32  HSC11
# 33  HSC12
# 34  HSC13
# 35  HSC14
# 36  HSC15
# 37  HSC16
# 38  HSC17
# 39  HSC54
# 40  HSC18
# 41  HSC19
# 42  HSC20
# 43  HSC21
# 44  HSC22
# 45  HSC23
# 46  HSC24
# 47  HSC25
# 48  HSC26
# 49  HSC27
# 50  HSC28
# 51  HSC29
# 52  HSC30
# 53  HSC31
# 54  HSC32
# 55  HSC33
# 56  HSC34
# 57  HSC35
# 58  HSC36
# 59  HSC37
# 60  HSC38
# 61  HSC39
# 62  HSC40
# 63  HSC41
# 64  HSC42
# 65  HSC43
# 66  HSC44
# 67  HSC45
# 68  HSC46
# 69  HSC47
# 70  HSC48
# 71  HSC49
# 72  HSC50
# 73  HSC51
# 74  HSC52
# 75  HSC53
# 76  HSC55
# 77  HSC56
#
#                                                                              indicator  \
# 22  420-c Tax Exemption (properties)
# 23  420-c Tax Exemption (units)
# 24  421-a Tax Exemption (properties)
# 25  421-a Tax Exemption (units)
# 26  Eligible to expire from housing programs between 2020 and 2025 (properties)
# ...

# %%
lookup_table[lookup_table.alias.str[:3] == 'LUD']
# Out:
#    alias                                             indicator  \
# 78  LUD1  Population density (1,000 persons per square mile)
# 79  LUD2  Units authorized by new residential building permits
# 80  LUD3  Units issued new certificates of occupancy
#
#                                                                                                                             description
# 78  The geographic area's population divided by its land area and is reported in thousands of people per square mile.
# 79  The number of units authorized by new residential building permits is derived from the building permit and jobs reports of the DOB.
# 80  The number of residential units in buildings issued new certificates of occupancy issued by the DOB each year.

# %%
lookup_table[lookup_table.alias.str[:3] == 'NSC']
# Out:
#    alias  \
# 81  NSC1
# 82  NSC2
# 83  NSC3
# 84  NSC4
# 85  NSC5
# 86  NSC6
# 87  NSC7
#
#                                                                  indicator  \
# 81  Car-free commute (% of commuters)
# 82  Mean travel time to work (minutes)
# 83  Serious crime rate (per 1,000 residents)
# 84  Serious crime rate, property (per 1,000 residents)
# 85  Serious crime rate, violent (per 1,000 residents)
# 86  Students performing at grade level in English language arts, 4th grade
# 87  Students performing at grade level in math, 4th grade
#
#                                                                                                                                                           description
# 81  The percentage of workers who commute primarily by foot, bicycle, or public transportation, as a share of all workers over the age of 16 who do not work at home.
# 82  The mean commute time in minutes for commuters residing in the geographic area.
# ...

# %%
lookup_table[lookup_table.alias.str[:3] == 'RNT']
# Out:
#      alias  \
# 88   RNT1
# 89   RNT2
# 90   RNT3
# 91   RNT4
# 92   RNT5
# 93   RNT6
# 94   RNT7
# 95   RNT8
# 96   RNT9
# 97   RNT10
# 98   RNT11
# 99   RNT12
# 100  RNT13
# 101  RNT14
# 102  RNT15
# 103  RNT16
#
#                                                                  indicator  \
# 88   Housing choice vouchers (% of occupied, privately owned rental units)
# 89   Median rent, 2- and 3-bedrooms (2019$)
# 90   Median rent, all (2019$)
# 91   Median rent, asking
# 92   Median rent, recent movers (2019$)
# 93   Median rent, studios and 1-bedrooms (2019$)
# 94   Moderately rent-burdened households
# 95   Moderately rent-burdened households, low income
# 96   Moderately rent-burdened households, moderate income
# 97   Public housing (% of rental units)
# 98   Rental units affordable at  30% AMI (% of recently available units)
# 99   Rental units affordable at  80% AMI (% of recently available units)
# 100  Rental units affordable at 120% AMI (% of recently available units)
# ...

# %%
profile_df = """SELECT * FROM profile"""
profile_df = Queries.execute_query(conn, description_query, to_frame=True)

# %%
profile_df.head()
# Out:
#    code   dem1   dem2   dem3   dem4  dem5   dem6      dem7      dem8     dem9  \
# 0  BK01  0.518  0.059  0.200  0.239  8.1   0.714  81990.0   127140.0  74440.0
# 1  BK02  0.460  0.070  0.187  0.247  7.7   0.731  110230.0  163720.0  89540.0
# 2  BK03  0.588  0.078  0.195  0.283  7.2   0.648  55910.0   91750.0   46660.0
# 3  BK04  0.458  0.090  0.276  0.232  6.4   0.663  54240.0   92300.0   49620.0
# 4  BK05  0.545  0.068  0.356  0.379  5.5   0.580  42060.0   76180.0   34980.0
#
#    ...   rnt7   rnt8   rnt9  rnt10  rnt11  rnt12  rnt13  rnt14  rnt15  rnt16
# 0  ...  0.223  0.267  0.366  0.066  0.056  0.218  0.507  0.267  0.485  0.084
# 1  ...  0.208  0.265  0.408  0.160  0.049  0.154  0.442  0.192  0.392  0.067
# 2  ...  0.270  0.284  0.292  0.171  0.085  0.413  0.893  0.294  0.425  0.024
# 3  ...  0.264  0.271  0.298  0.108  0.070  0.409  0.851  0.318  0.459  0.019
# 4  ...  0.255  0.301  0.061  0.157  0.182  0.860  0.995  0.329  0.418  0.000
#
# [5 rows x 80 columns]

# %% [markdown]
# Things to Mention:
# - Values that are between 0 and 1 were percentages. For example DEM1 is the percentage of people born in the state of NY. For BK01 that statement applies to 51.8 percent of the total population
